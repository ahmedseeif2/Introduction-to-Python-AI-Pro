# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class shape:
    def __init_(self):
        pass

# %%
class twoDshape(shape):
    def __init__(self):
        pass

# %%
class circle(twoDshape):
    def __init__(self):
        pass

# %%
class square(twoDshape):
    def __init__(self):
        pass

# %%
class triangle(twoDshape):
    def __init__(self):
        pass

# %%
class threeDshape(shape):
    def __init__(self):
        pass

# %%
class Sphere(threeDshape):
    def __init__(self):
        pass

# %%
class Cube(threeDshape):
    def __init__(self):
        pass

# %%
class Tetrahedron(threeDshape):
    def __init__(self):
        pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class CommunityMember:
    def __init__(self):
        pass

# %%
class Employee(CommunityMember):
    pass

# %%
class Faculty(Employee):
    pass

# %%
class Staff(Employee):
    pass

# %%
class Adminstrator(Faculty):
    pass

# %%
class Teacher(Faculty):
    pass

# %%
class AdminstratorTeacher(Adminstrator,Teacher):
    pass

# %%
class Student(CommunityMember):
    pass

# %%
class Alumnus(CommunityMember):
    pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Customers:
    pass

# %%
class PaymentMethod(self,amount):
    self.amount = amount
    pass

# %%
class cash(PaymentMethod):
    pass

# %%
class cards(PaymentMethod):
    pass

# %%
class credit(cards):
    pass

# %%
class debt(cards):
    pass

# %%
class cheque(PaymentMethod):
    pass
